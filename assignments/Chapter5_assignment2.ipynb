# %% [markdown]
# # Chapter 5 提出課題 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### データの読み込み

# %%
X_train=pd.read_csv("./data/X_train.csv")
y_train=pd.read_csv("./data/y_train.csv")
X_test=pd.read_csv("./data/X_test.csv")
display(X_train.head())
# Out:
#    平均気温  最高気温  最低気温  降水量の合計  平均風速  最大風速 最多風向  最大瞬間風速  平均蒸気圧  平均湿度  最小相対湿度  \
# 0  22.4  23.6  20.3     0.0   2.8   5.0   北東     7.6   18.3    67      56
# 1  18.2  21.3  14.9     6.5   2.8   5.3  北北東     9.8   16.2    78      63
# 2  25.8  31.1  22.3     0.0   2.7   5.3  東北東    10.4   25.9    79      52
# 3  18.4  23.0  16.2     0.0   2.8   5.2  東北東     9.4   16.7    80      53
# 4  25.7  29.6  23.0     0.0   1.8   3.5  北北東     5.6   26.6    81      64
#
#    平均現地気圧  平均海面気圧  最低海面気圧
# 0  1013.9  1016.7  1015.2
# 1  1016.9  1019.8  1017.5
# 2  1006.5  1009.3  1004.7
# 3  1018.5  1021.4  1017.5
# 4  1015.6  1018.4  1016.7

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (28, 14)
# (28, 1)
# (28, 14)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 14 columns):
# 平均気温      28 non-null float64
# 最高気温      28 non-null float64
# 最低気温      28 non-null float64
# 降水量の合計    28 non-null float64
# 平均風速      28 non-null float64
# 最大風速      28 non-null float64
# 最多風向      28 non-null object
# 最大瞬間風速    28 non-null float64
# 平均蒸気圧     28 non-null float64
# 平均湿度      28 non-null int64
# 最小相対湿度    28 non-null int64
# 平均現地気圧    28 non-null float64
# 平均海面気圧    28 non-null float64
# 最低海面気圧    28 non-null float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 3.1+ KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 1 columns):
# 目的変数    28 non-null float64
# dtypes: float64(1)
# memory usage: 304.0 bytes

# %% [markdown]
# ### 数値でないデータの処理

# %%
display(X_train['最多風向'].head())
# Out:
# 0     北東
# 1    北北東
# 2    東北東
# 3    東北東
# 4    北北東
# Name: 最多風向, dtype: object

# %% [markdown]
# ### ”最大風向”を”sin”，”cos”で表す．

# %%
SIN={
    "北"    : np.sin(np.pi*0/16),
    "北北東": np.sin(np.pi*1/16),
    "北東"  : np.sin(np.pi*2/16),
    "東北東": np.sin(np.pi*3/16),
    "東"    : np.sin(np.pi*4/16),
    "東南東": np.sin(np.pi*5/16),
    "南東"  : np.sin(np.pi*6/16),
    "南南東": np.sin(np.pi*7/16),
    "南"    : np.sin(np.pi*8/16),
    "南南西": np.sin(np.pi*9/16),
    "南西"  : np.sin(np.pi*10/16),
    "西南西": np.sin(np.pi*11/16),
    "西"    : np.sin(np.pi*12/16),
    "西北西": np.sin(np.pi*13/16),
    "北西"  : np.sin(np.pi*14/16),
    "北北西": np.sin(np.pi*15/16)
}

COS={
    "北"    : np.cos(np.pi*0/16),
    "北北東": np.cos(np.pi*1/16),
    "北東"  : np.cos(np.pi*2/16),
    "東北東": np.cos(np.pi*3/16),
    "東"    : np.cos(np.pi*4/16),
    "東南東": np.cos(np.pi*5/16),
    "南東"  : np.cos(np.pi*6/16),
    "南南東": np.cos(np.pi*7/16),
    "南"    : np.cos(np.pi*8/16),
    "南南西": np.cos(np.pi*9/16),
    "南西"  : np.cos(np.pi*10/16),
    "西南西": np.cos(np.pi*11/16),
    "西"    : np.cos(np.pi*12/16),
    "西北西": np.cos(np.pi*13/16),
    "北西"  : np.cos(np.pi*14/16),
    "北北西": np.cos(np.pi*15/16)
}

# %%
X_train['sin']=X_train['最多風向'].map(SIN)
X_train['cos']=X_train['最多風向'].map(COS)

X_test['sin']=X_test['最多風向'].map(SIN)
X_test['cos']=X_test['最多風向'].map(COS)

# %%
display(X_train.head())
# Out:
#    平均気温  最高気温  最低気温  降水量の合計  平均風速  最大風速 最多風向  最大瞬間風速  平均蒸気圧  平均湿度  最小相対湿度  \
# 0  22.4  23.6  20.3     0.0   2.8   5.0   北東     7.6   18.3    67      56
# 1  18.2  21.3  14.9     6.5   2.8   5.3  北北東     9.8   16.2    78      63
# 2  25.8  31.1  22.3     0.0   2.7   5.3  東北東    10.4   25.9    79      52
# 3  18.4  23.0  16.2     0.0   2.8   5.2  東北東     9.4   16.7    80      53
# 4  25.7  29.6  23.0     0.0   1.8   3.5  北北東     5.6   26.6    81      64
#
#    平均現地気圧  平均海面気圧  最低海面気圧       sin       cos
# 0  1013.9  1016.7  1015.2  0.382683  0.923880
# 1  1016.9  1019.8  1017.5  0.195090  0.980785
# 2  1006.5  1009.3  1004.7  0.555570  0.831470
# 3  1018.5  1021.4  1017.5  0.555570  0.831470
# 4  1015.6  1018.4  1016.7  0.195090  0.980785

# %%
X_train=X_train.drop("最多風向",axis=1)
X_test=X_test.drop("最多風向",axis=1)

display(X_train.head())
# Out:
#    平均気温  最高気温  最低気温  降水量の合計  平均風速  最大風速  最大瞬間風速  平均蒸気圧  平均湿度  最小相対湿度  平均現地気圧  \
# 0  22.4  23.6  20.3     0.0   2.8   5.0     7.6   18.3    67      56  1013.9
# 1  18.2  21.3  14.9     6.5   2.8   5.3     9.8   16.2    78      63  1016.9
# 2  25.8  31.1  22.3     0.0   2.7   5.3    10.4   25.9    79      52  1006.5
# 3  18.4  23.0  16.2     0.0   2.8   5.2     9.4   16.7    80      53  1018.5
# 4  25.7  29.6  23.0     0.0   1.8   3.5     5.6   26.6    81      64  1015.6
#
#    平均海面気圧  最低海面気圧       sin       cos
# 0  1016.7  1015.2  0.382683  0.923880
# 1  1019.8  1017.5  0.195090  0.980785
# 2  1009.3  1004.7  0.555570  0.831470
# 3  1021.4  1017.5  0.555570  0.831470
# 4  1018.4  1016.7  0.195090  0.980785

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (28, 15)
# (28, 15)

# %% [markdown]
# ### リッジ回帰のクラス

# %%
from sklearn.base import BaseEstimator,RegressorMixin
from sklearn.utils.validation import check_X_y,check_is_fitted,check_array

# %%
class MyLinearRegression(BaseEstimator,RegressorMixin):
    def __init__(self,lam=0,a=None,b=None):
        self.a=a
        self.b=b
        self.lam=lam
        
    def fit(self,X,y):
        X, y = check_X_y(X, y, y_numeric=True)
        
        if self.lam != 0:
            pass
        else:
            pass

        one=np.ones(X.shape[0]).reshape(-1,1)
        X_=np.concatenate((one,X),axis=1)
        Lam=self.lam*np.eye(X_.shape[1])
        A=Lam+np.dot(X_.T,X_)
        X_daggar=np.dot(np.linalg.inv(A),X_.T)
        w=np.dot(X_daggar,y)
        
        self.a_=w[1:]
        self.b_=w[0]
        
        return self
    
    def predict(self,X):
        X=check_array(X)
        y=np.dot(X,self.a_)+self.b_
        
        check_is_fitted(self, "a_", "b_") # 学習済みかチェックする(推奨)
        X = check_array(X)
        return y

# %% [markdown]
# ### X_train, y_trainを用いて学習

# %%
from sklearn.model_selection import GridSearchCV

np.random.seed(0)

# Grid search
parameters = {'lam':np.exp([i for i in range(-30,1)])}
reg = GridSearchCV(MyLinearRegression(),parameters,cv=5)
reg.fit(X_train,y_train)
best = reg.best_estimator_

# 決定係数
print("決定係数: ", best.score(X_train, y_train)) # BaseEstimatorを継承しているため使える
# lambda
print("lam: ", best.lam)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ### X_testの予測値をy_predに出力

# %%
y_pred=best.predict(X_test)
np.savetxt("./data/y_pred.csv",y_pred,delimiter=',')

# %%
y_pred=pd.read_csv("./data/y_pred.csv")
y_pred=y_pred.
display(y_pred.head())
# Out:
#    -5.859223812148452559e+00
# 0                   7.320348
# 1                   5.055719
# 2                   4.482367
# 3                   3.579165
# 4                  -1.125680
